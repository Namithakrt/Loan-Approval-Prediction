# %% [markdown]
# <a href="https://colab.research.google.com/github/Namithakrt/Loan-Approval-Prediction/blob/main/LoanApprovalPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LOAD DATA SET

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/loan.csv.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.size
# Out:
# 7982

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# # VISUALIZATION

# %%
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# <ipython-input-9-534f4f3c80b7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
sns.countplot(x=df['Loan_Status'],data=df)
# Out:
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
#422 people out of 614 got loan approval

# %%
sns.countplot(x=df['Gender'],data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#80% applicants are male

# %%
sns.countplot(x=df['Married'],data=df)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
#65% applicants are married

# %%
sns.countplot(x=df['Self_Employed'],data=df)
# Out:
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
#15% applicants are self-employed

# %%
sns.countplot(x=df['Credit_History'],data=df)
# Out:
# <Axes: xlabel='Credit_History', ylabel='count'>

# %%
#80% people repaid their debts

# %%
sns.countplot(x=df['Dependents'],data=df)
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
#most of the poeple doesn't have applicants

# %%
sns.countplot(x=df['Education'],data=df)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
#about 80% people are graduates

# %%
sns.countplot(x=df['Property_Area'],data=df)
# Out:
# <Axes: xlabel='Property_Area', ylabel='count'>

# %%
#most of the people are from semi-urban areas

# %%
sns.boxplot(y=df['ApplicantIncome'],data=df)
# Out:
# <Axes: ylabel='ApplicantIncome'>

# %%
sns.boxplot(y=df['CoapplicantIncome'],data=df)
# Out:
# <Axes: ylabel='CoapplicantIncome'>

# %%
sns.boxplot(y=df['LoanAmount'],data=df)
# Out:
# <Axes: ylabel='LoanAmount'>

# %% [markdown]
# # HANDLING MISSING VALUES

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df['Married']=df['Married'].fillna(df['Married'].mode()[0])

# %%
df['Dependents']=df['Dependents'].fillna(df['Dependents'].mode()[0])

# %%
df['Self_Employed']=df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0])

# %%
df['Credit_History']=df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].median())

# %%
df.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df['Dependents']=df['Dependents'].replace('3+',int(3))

# %%
df['Dependents']=df['Dependents'].astype(int)

# %% [markdown]
# # ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])
df['Education']=le.fit_transform(df['Dependents'])
df['Married']=le.fit_transform(df['Married'])
df['Self_Employed']=le.fit_transform(df['Self_Employed'])
df['Property_Area']=le.fit_transform(df['Property_Area'])

# %%
df1=df.drop(['Loan_ID'],axis=1)

# %%
df1
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          1              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          3              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          2              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
x=df1.drop(['Loan_Status'],axis=1)
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0             5849
# 1         1        1           1          1              0             4583
# 2         1        1           0          0              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          0              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0             2900
# 610       1        1           3          3              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          2              0             7583
# 613       0        0           0          0              1             4583
#
# ...

# %%
y=df['Loan_Status']
y
# Out:
# 0      Y
# 1      N
# 2      Y
# 3      Y
# 4      Y
#       ..
# 609    Y
# 610    Y
# 611    Y
# 612    Y
# 613    N
# Name: Loan_Status, Length: 614, dtype: object

# %% [markdown]
# TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 553       1        1           0          0              0             2454
# 601       1        1           0          0              0             2894
# 261       1        0           0          0              0             2060
# 496       1        1           0          0              0             2600
# 529       1        0           0          0              0             6783
# ..      ...      ...         ...        ...            ...              ...
# 71        1        1           2          2              1             1875
# 106       1        1           2          2              0            11417
# 270       0        0           0          0              0             3237
# 435       0        1           0          0              0            10047
# 102       1        1           0          0              0            13650
#
# ...

# %%
x_test
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 350       1        1           0          0              0             9083
# 377       1        1           0          0              0             4310
# 163       1        1           2          2              0             4167
# 609       0        0           0          0              0             2900
# 132       1        0           0          0              0             2718
# ..      ...      ...         ...        ...            ...              ...
# 380       1        1           0          0              0             3333
# 446       1        1           2          2              0             4652
# 144       1        1           2          2              0            11757
# 290       1        1           0          0              0             3075
# 353       0        1           0          0              1             5500
#
# ...

# %%
y_train
# Out:
# 553    N
# 601    Y
# 261    Y
# 496    Y
# 529    Y
#       ..
# 71     Y
# 106    Y
# 270    Y
# 435    Y
# 102    Y
# Name: Loan_Status, Length: 429, dtype: object

# %%
y_test
# Out:
# 350    Y
# 377    Y
# 163    Y
# 609    Y
# 132    Y
#       ..
# 380    Y
# 446    Y
# 144    Y
# 290    Y
# 353    N
# Name: Loan_Status, Length: 185, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array(['Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'N', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'N', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y',
#        'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,ConfusionMatrixDisplay

# %%
mat=confusion_matrix(y_test,y_pred)
cmd=ConfusionMatrixDisplay(mat)
cmd.plot()

# %%
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.7837837837837838
